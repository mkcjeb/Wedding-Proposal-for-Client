# %% [markdown]
# <hr style="height:1px;border:none;color:#333;background-color:#333;" />
# <hr style="height:1px;border:none;color:#333;background-color:#333;" />
# <br>
#
# # <span style='font-family: "Arial"; font-size: 32px;'>WEDDING EVENT PROPOSAL</span><br>
#
#
# Team 07 The Matrix Bliss Events<br>
# BCH-7810: Business Challenge I <br>
# Master’s degree on Business Analytics, Hult International Business School<br>
# Professor Chase Kusterer<br>
# December 20, 2023 <br>
# <br><br>
#
# <hr style="height:1px;border:none;color:#333;background-color:#333;" />
# <hr style="height:1px;border:none;color:#333;background-color:#333;" />

# %% [markdown]
# ### Dear Bride & Groom,
#
# <em>&emsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;Congratulations on your engagement!<br>
#     &emsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;Ready to start planning the best day of your lives?</em><br>
#
# Choose our services for your wedding and entrust the planning to the very best hands, leaving you absolutely relaxed to enjoy the best day of your lives!<br>
#
# &emsp;&emsp;&emsp;&nbsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp; - The Matrix Bliss Events

# %% [markdown]
# <div class="alert alert-block alert-success">
# Proving  the elegance of simplicity in color palettes, this ethereal styled wedding presentation showcases greenery-filled floral arrangements. It offers exquisite styling inspiration for a romantic-vintage wedding, all presented in the heavenly hues of dusty blue.
# </div>

# %% [markdown]
# <div class="alert alert-block alert-info">
#     <b>Wedding Theme:</b> Romantic + Vintage &emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;<b>Setting:</b>&emsp;&emsp;Indoor + Outdoor  <br>
#     <b>Color:</b>&emsp;&emsp;&emsp;&emsp;&emsp; Dusty Blue &emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;<b>Location:</b>&emsp;601 Murray Cir, Sausalito, CA 94965
# </div>
# <br>
#
# <div style="display: flex; justify-content: center; align-items: center;">
# <img src="theme.jpg" alt="theme.jpg" width="300" height="200" style="float:left; margin-right: -200px;" />
# <img src="invitation.png" alt="invitation.png" width="200" height="200" style="margin: 0 240px;" />
# </div>
# </div>
# </div>

# %% [markdown]
# <div class="alert alert-block alert-warning" style="text-align: center; font-family: 'Calibri Light', sans-serif; font-size: 18px;">
# VENDORS<br>
# <hr>
# <span style='font-family: "Arial"; font-size: 14px; color: gray; display: block; text-align: left;'>&emsp;&emsp;VENUE: Cavallo Point The Lodge at the Golden Gate&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;HAIR & MAKEUP: Shineforth Salon and The Pretty Committee &emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;<br><br>
# &emsp;&emsp;RENTALS: Eventlyst &emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;DRESS & ATTIRE: Stacees (Bride Dress), Blacktux (Tie), Misaac (B.maid Dress) &emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;
# <br>&emsp;&emsp;CATERING: Fogcutter &emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp; &emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;JEWELRY: Diamondere <br><br>
# &emsp;&emsp;FLOWERS: Expressions Floral &emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp; PHOTO AND VIDEO: Danny Rey Films<br> <br>
# &emsp;&emsp;INVITATION:The Knot & Paper culture &emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;MUSIC: iMobile DJs <br> <br>
# <span>
# </div>
# </div>

# %%
# Importing pandas libraries
import pandas as pd

# %%
# Storing the path to the dataset
# Change the path to './wedding_cost_data.xlsx' before the submit
path = './wedding_cost_data.xlsx'

# Instantiating the dataset as an object
wedding_data = pd.read_excel(path)

# Displaying the first 5 rows of the dataset
wedding_data.head(n=5)
# Out:
#    category         vendor_name  budget_level  \
# 0   Flowers  Expressions Floral           980
# 1   Flowers  Expressions Floral           980
# 2   Flowers  Expressions Floral           980
# 3  Catering           Fogcutter         12570
# 4  Catering           Fogcutter         12570
#
#                             item_name  price_per_item  quantity  subtotal
# 0  Wonderful White Bouquet of Flowers            65.0         1     65.00
# 1        Classic White Bridal Bouquet            65.0         1     65.00
# 2           Whimsical Wispies Bouquet           160.0         1    160.00
# 3                      Plated Serving           110.0       114  12508.10
# 4                Panna Cotta Shooters             3.0       114    341.13

# %%
# Defining a function to break down cost by department
def department_breakdown(data, department):

    # Filtering the dataset to include only the specified department
    filter = (data['category'] == department)
    depart_data = data[filter]
    
    print(f"""From our {department} department we prepared {depart_data.shape[0]} unique product/s!
    """)
    
    # Displaying a breakdown of each product, including vendor, quantity, price, and total cost
    for number,product in depart_data.iterrows():
        
        print(f"""{number+1}. {product['item_name']} provided by {product['vendor_name']}
                                                                                        {product['quantity']} x {round(product['price_per_item'],2)}$ = {product['subtotal']}$""")

    print(f"""
                                                                                        Total:      {round(depart_data['subtotal'].sum(),2)}$""")
    print('------------------------------------------------------------------------------------------------------------')

# %%
# Defining a function to calculate and display the total cost for a specific department
def department_total(data, department):

    # Filtering the dataset to include only the specified department
    filter = (data['category'] == department)
    depart_data = data[filter]
    
    # Displaying the total cost for the specified department.
    print(f"""{department}  total: 
                                  {round(depart_data['subtotal'].sum(),2)}$""")

# %%
# Importing package for colored text and background
from IPython.display import HTML, display

# Defining a function to print colored text with specified background color, text color, and font size
def print_colored(text, background_color, text_color, font_size="16px"):
    style = f"background-color: rgb({background_color}); color: {text_color}; padding: 8px; font-weight: bold; font-size: {font_size}; text-align: center;"
    html_text = f"<div style='{style}'>{text}</div>"
    display(HTML(html_text))

# Displaying a header with colored text, background, and specified font size
print_colored("VENDORS & PRICING", background_color="120,190,210", text_color="white", font_size="40px")

departments = wedding_data['category'].unique()
print(f"""
Guest:  135
Budget: 40000$
          """)

# Iterating through unique departments and displaying breakdown and total
for department in departments:
    department_breakdown(wedding_data, department)

for department in departments:
    department_total(wedding_data, department)


print("******************************************")
# Displaying the overall total cost for the wedding with colored background and bold text
total_cost = str(wedding_data['subtotal'].sum())
formatted_total_cost = '\x1b[1m\x1b[41;184;219;46m' + f'Wedding Cost:                    {round(float(total_cost), 2)}$' + '\x1b[0m\x1b[0m'  # Adding ANSI escape codes for bold and color
print(formatted_total_cost)
# Out:
# <div style='background-color: rgb(120,190,210); color: white; padding: 8px; font-weight: bold; font-size: 40px; text-align: center;'>VENDORS & PRICING</div>
# Guest:  135
# Budget: 40000$
#
# From our Flowers department we prepared 3 unique product/s!
#
# 1. Wonderful White Bouquet of Flowers provided by Expressions Floral
#                                                                                         1 x 65.0$ = 65.0$
# 2. Classic White Bridal Bouquet provided by Expressions Floral
#                                                                                         1 x 65.0$ = 65.0$
# 3. Whimsical Wispies Bouquet provided by Expressions Floral
#                                                                                         1 x 160.0$ = 160.0$
#
#                                                                                         Total:      290.0$
# ------------------------------------------------------------------------------------------------------------
# From our Catering department we prepared 3 unique product/s!
#
# 4. Plated Serving provided by Fogcutter
#                                                                                         114 x 110.0$ = 12508.1$
# 5. Panna Cotta Shooters provided by Fogcutter
#                                                                                         114 x 3.0$ = 341.13$
# 6. Three Tier Cake provided by Fogcutter
#                                                                                         1 x 350.0$ = 350.0$
#
#                                                                                         Total:      13199.23$
# ------------------------------------------------------------------------------------------------------------
# From our Invitation department we prepared 5 unique product/s!
#
# 7. RSVP provided by Paper Culture
#                                                                                         135 x 3.93$ = 530.55$
# 8. Invitation provided by The Knot
#                                                                                         135 x 0.89$ = 120.15$
# 9. Envelope liner provided by The Knot
#                                                                                         135 x 3.52$ = 475.2$
# 10. Wedding Program provided by The Knot
#                                                                                         135 x 0.5$ = 67.5$
# 11. Menu provided by Paper Culture
#                                                                                         135 x 1.18$ = 159.3$
#
#                                                                                         Total:      1352.7$
# ------------------------------------------------------------------------------------------------------------
# From our Dress and Attire department we prepared 4 unique product/s!
#
# 12. Groom's suit and Bowtie provided by Blacktux
#                                                                                         1 x 159.0$ = 159.0$
# 13. Groomsmen Suit and Tie provided by Blacktux
#                                                                                         8 x 159.0$ = 1272.0$
# 14. Bridal Gown provided by Stacees
#                                                                                         1 x 417.0$ = 417.0$
# 15. Bridemaid's Dresses provided by Misaac
#                                                                                         8 x 99.0$ = 792.0$
#
#                                                                                         Total:      2640.0$
# ------------------------------------------------------------------------------------------------------------
# From our Hair and Makeup department we prepared 2 unique product/s!
#
# 16. Bridal Party Hair & Makeup (Airbrush) provided by Shineforth Salon
#                                                                                         9 x 275.0$ = 2475.0$
# 17. Groom Party Hair & Makeup (Simple) provided by The Pretty Committee
#                                                                                         9 x 63.0$ = 567.0$
#
#                                                                                         Total:      3042.0$
# ------------------------------------------------------------------------------------------------------------
# From our Jewelry department we prepared 1 unique product/s!
#
# 18. Wedding Ring provided by Diamondere
#                                                                                         2 x 1275.0$ = 2550.0$
#
#                                                                                         Total:      2550.0$
# ------------------------------------------------------------------------------------------------------------
# From our Music department we prepared 1 unique product/s!
#
# 19. Music provided by iMobile DJs
#                                                                                         1 x 1895.0$ = 1895.0$
#
#                                                                                         Total:      1895.0$
# ------------------------------------------------------------------------------------------------------------
# From our Photo and Video department we prepared 1 unique product/s!
#
# 20. Wedding Photoshoot provided by Danny Rey Films
#                                                                                         1 x 2291.0$ = 2291.0$
#
#                                                                                         Total:      2291.0$
# ------------------------------------------------------------------------------------------------------------
# From our Venues department we prepared 1 unique product/s!
#
# 21. Wedding Venue provided by Cavallo Point the Lodge at the Golden Gate
#                                                                                         1 x 9500.0$ = 9500.0$
#
#                                                                                         Total:      9500.0$
# ------------------------------------------------------------------------------------------------------------
# From our Rentals department we prepared 31 unique product/s!
#
# 22. Cross Back Farm Chair provided by Eventlyst
#                                                                                         114 x 4.0$ = 456.0$
# 23. Clear Chiavari Chairs provided by Eventlyst
#                                                                                         114 x 5.0$ = 570.0$
# 24. Beige Loveseat provided by Eventlyst
#                                                                                         1 x 40.0$ = 40.0$
# 25. Farmhouse Tables Rental 8 Pax provided by Eventlyst
#                                                                                         17 x 20.0$ = 340.0$
# 26. Natural Sweetheart Table provided by Eventlyst
#                                                                                         1 x 30.0$ = 30.0$
# 27. White Dessert Table provided by Eventlyst
#                                                                                         4 x 50.0$ = 200.0$
# 28. White Vintage Table provided by Eventlyst
#                                                                                         1 x 20.0$ = 20.0$
# 29. Wooden Stumps Or Wood Slices for Cake provided by Eventlyst
#                                                                                         1 x 2.5$ = 2.5$
# 30. Lavender And Eucalyptus Garland 6 Ft provided by Eventlyst
#                                                                                         18 x 6.0$ = 108.0$
# 31. Table Garland provided by Eventlyst
#                                                                                         18 x 10.0$ = 180.0$
# 32. Table Numbers provided by Eventlyst
#                                                                                         17 x 2.5$ = 42.5$
# 33. Dusty Blue Table Runner 10 Ft provided by Eventlyst
#                                                                                         18 x 4.0$ = 72.0$
# 34. Dusty Blue Drape 10 Ft provided by Eventlyst
#                                                                                         18 x 4.0$ = 72.0$
# 35. Dusty Blue Napkins Linen provided by Eventlyst
#                                                                                         114 x 0.5$ = 57.0$
# 36. Boxwood Greenery Backdrop provided by Eventlyst
#                                                                                         1 x 30.0$ = 30.0$
# 37. Copper Background Stand or Arch provided by Eventlyst
#                                                                                         1 x 25.0$ = 25.0$
# 38. White Chiffon Backdrop Drape provided by Eventlyst
#                                                                                         1 x 9.0$ = 9.0$
# 39. 6 Ft White Peony Garland provided by Eventlyst
#                                                                                         1 x 10.0$ = 10.0$
# 40. Walnut Wood Welcome Sign provided by Eventlyst
#                                                                                         1 x 75.0$ = 75.0$
# 41. Gold Flatware Set 3 Piece provided by Eventlyst
#                                                                                         114 x 1.0$ = 114.0$
# 42. Gold Beaded Glass Chargers provided by Eventlyst
#                                                                                         114 x 0.5$ = 57.0$
# 43. White Dinner Plate provided by Eventlyst
#                                                                                         114 x 0.5$ = 57.0$
# 44. White Dessert Plates provided by Eventlyst
#                                                                                         114 x 0.5$ = 57.0$
# 45. White Salad Plates provided by Eventlyst
#                                                                                         114 x 0.5$ = 57.0$
# 46. Champagne Flutes provided by Eventlyst
#                                                                                         114 x 0.5$ = 57.0$
# 47. Dark Blue Goblet provided by Eventlyst
#                                                                                         114 x 1.0$ = 114.0$
# 48. Light Blue Goblet provided by Eventlyst
#                                                                                         114 x 1.0$ = 114.0$
# 49. Gold Tea Light Candle Holders provided by Eventlyst
#                                                                                         26 x 0.5$ = 13.0$
# 50. Gold Candle Holders provided by Eventlyst
#                                                                                         60 x 0.5$ = 30.0$
# 51. Dusty Blue 10 Inches Premium Wax Taper Candles provided by Eventlyst
#                                                                                         60 x 1.0$ = 60.0$
# 52. Wood And Antiqued Brass 2 Tier Serving Dessert Stand provided by Eventlyst
#                                                                                         8 x 1.1$ = 8.8$
#
#                                                                                         Total:      3077.8$
# ------------------------------------------------------------------------------------------------------------
# Flowers  total:
#                                   290.0$
# Catering  total:
#                                   13199.23$
# Invitation  total:
#                                   1352.7$
# Dress and Attire  total:
#                                   2640.0$
# Hair and Makeup  total:
#                                   3042.0$
# Jewelry  total:
#                                   2550.0$
# Music  total:
#                                   1895.0$
# Photo and Video  total:
#                                   2291.0$
# Venues  total:
#                                   9500.0$
# Rentals  total:
#                                   3077.8$
# ******************************************
# Wedding Cost:                    39837.73$

# %% [markdown]
# ~~~
#                   ______                                       _            _                  _
#                  / _____)                            _        | |      _   (_)                | |
#                 | /      ___  ____   ____  ____ ____| |_ _   _| | ____| |_  _  ___  ____   ___| |
#                 | |     / _ \|  _ \ / _  |/ ___) _  |  _) | | | |/ _  |  _)| |/ _ \|  _ \ /___)_|
#                 | \____| |_| | | | ( ( | | |  ( ( | | |_| |_| | ( ( | | |__| | |_| | | | |___ |_
#                  \______)___/|_| |_|\_|| |_|   \_||_|\___)____|_|\_||_|\___)_|\___/|_| |_(___/|_|
#                                    (_____|
#
# ~~~

# %% [markdown]
# <b>References</b>
#
# Aisle Society. Modern Renaissance Wedding. https://www.aislesociety.com/post/modern-renaissance-wedding-inspiration <br>
# Better Proposals. Wedding Planner. https://betterproposals.io/proposal-templates/wedding-planner-proposal-template <br>
# Eventlyst. Event Rental Marketplace. https://eventlyst.com/locations/sacramento-party-rentals/ <br>
# McHale's Events and Catering. Estimating Guest Counts. https://mchalescatering.com/wedding-guest-counts/<br>
# Stack Overflow. Printing text. https://stackoverflow.com/questions/23271575/printing-bold-colored-etc-text-in-ipython-qtconsole/46934204#46934204
# RSVPify. Percent of Guest List Expected. https://rsvpify.com/percent-of-guest-list-expected-to-come-wedding/<br>
# Zazzle. Dusty Blue & Gray Wedding Color Palette Card. https://www.zazzle.com/dusty_blue_gray_wedding_color_palette_card-256824042859136860 <br>
